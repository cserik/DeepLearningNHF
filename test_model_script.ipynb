# %% [markdown]
# <a href="https://colab.research.google.com/github/cserik/DeepLearningNHF/blob/main/test_model_script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import load_model
from matplotlib import pyplot as plt
from numpy import zeros
from numpy.random import randn

# %% [markdown]
# **<--------Copy one of the model.h5 files from github to files tab(content directory)**

# %%
def generate_fake_samples(generator, latent_dim, n_samples):
	# generate points in latent space
	x_input = generate_latent_points(latent_dim, n_samples)
	# predict outputs
	X = generator.predict(x_input)
	# create class labels
	y = zeros((n_samples, 1))
	return X, y

# %%
def generate_latent_points(latent_dim, n_samples):
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	x_input = x_input.reshape(n_samples, latent_dim)
	return x_input

# %%
gmodel=load_model('/content/model_128x128-tuned.h5')
# generate images
X, _ = generate_fake_samples(gmodel, 200, 10)
# normalize pixel values to the range [0,1]
X = (X - X.min()) / (X.max() - X.min())
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
#choose an element of the array
plt.imshow(X[1], interpolation='nearest')
plt.show()
